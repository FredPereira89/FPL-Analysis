# %%
import pandas as pd
import numpy as np
import h2o
from h2o.automl import H2OAutoML
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.optimize import linprog
import requests
from datetime import datetime
from h2o.estimators.xgboost import H2OXGBoostEstimator
import ipywidgets as widgets
from IPython.display import display

# %%
# Base API URL
BASE_URL = "https://fantasy.premierleague.com/api"

# Helper function to calculate extra fields
def is_weekend(day):
    return 1 if day.lower() in ["saturday", "sunday"] else 0

# Fetch data from the main API endpoints
bootstrap_static = requests.get(f"{BASE_URL}/bootstrap-static/").json()
fixtures = requests.get(f"{BASE_URL}/fixtures/").json()

# Extract general data
players = pd.DataFrame(bootstrap_static['elements'])
teams = pd.DataFrame(bootstrap_static['teams'])
positions = pd.DataFrame(bootstrap_static['element_types'])

# Map team and position IDs to readable names
team_map = teams.set_index('id')['name'].to_dict()
position_map = positions.set_index('id')['singular_name_short'].to_dict()

players['team'] = players['team'].map(team_map)
players['position'] = players['element_type'].map(position_map)

# Add a new column for players' full names
players['full_name'] = players['first_name'] + " " + players['second_name']

# Prepare fixtures DataFrame for difficulty ratings
fixtures_df = pd.DataFrame(fixtures)
fixtures_df = fixtures_df[['id', 'team_h_difficulty', 'team_a_difficulty']]

# Prepare Gameweek-specific data
gameweek_data = []

for player_id in players['id']:
    # Fetch player-specific gameweek history
    player_data = requests.get(f"{BASE_URL}/element-summary/{player_id}/").json()
    history = player_data['history']
    
    for match in history:
        kickoff_datetime = datetime.strptime(match['kickoff_time'], '%Y-%m-%dT%H:%M:%SZ')
        kickoff_day = kickoff_datetime.strftime('%A')
        kickoff_hour = kickoff_datetime.hour

        # Fetch difficulty ratings from fixtures data
        fixture_data = fixtures_df[fixtures_df['id'] == match['fixture']]
        team_h_difficulty = fixture_data['team_h_difficulty'].values[0] if not fixture_data.empty else None
        team_a_difficulty = fixture_data['team_a_difficulty'].values[0] if not fixture_data.empty else None

        # Calculate transfers_balance
        transfers_in = players.loc[players['id'] == player_id, 'transfers_in'].values[0]
        transfers_out = players.loc[players['id'] == player_id, 'transfers_out'].values[0]
        transfers_balance = transfers_in - transfers_out

        gameweek_data.append({
            'name': players.loc[players['id'] == player_id, 'full_name'].values[0],  # Use full_name here
            'position': players.loc[players['id'] == player_id, 'position'].values[0],
            'team': players.loc[players['id'] == player_id, 'team'].values[0],
            'xP': match.get('expected_points', 0),
            'assists': match['assists'],
            'bonus': match['bonus'],
            'bps': match['bps'],
            'clean_sheets': match['clean_sheets'],
            'creativity': match['creativity'],
            'element': player_id,
            'expected_assists': match.get('xA', 0),
            'expected_goal_involvements': match.get('xGI', 0),
            'expected_goals': match.get('xG', 0),
            'expected_goals_conceded': match.get('xGC', 0),
            'fixture': match['fixture'],
            'goals_conceded': match['goals_conceded'],
            'goals_scored': match['goals_scored'],
            'ict_index': match['ict_index'],
            'influence': match['influence'],
            'kickoff_time': kickoff_datetime,
            'minutes': match['minutes'],
            'opponent_team': match['opponent_team'],
            'own_goals': match['own_goals'],
            'penalties_missed': match['penalties_missed'],
            'penalties_saved': match['penalties_saved'],
            'red_cards': match['red_cards'],
            'round': match['round'],
            'saves': match['saves'],
            'selected': players.loc[players['id'] == player_id, 'selected_by_percent'].values[0],
            'starts': int(match['minutes'] > 0),
            'team_a_score': match['team_a_score'],
            'team_h_score': match['team_h_score'],
            'threat': match['threat'],
            'total_points': match['total_points'],
            'transfers_balance': transfers_balance,
            'transfers_in': transfers_in,
            'transfers_out': transfers_out,
            'value': players.loc[players['id'] == player_id, 'now_cost'].values[0],
            'was_home': match['was_home'],
            'yellow_cards': match['yellow_cards'],
            'GW': match['round'],
            'team_h_difficulty': team_h_difficulty,
            'team_a_difficulty': team_a_difficulty,
            'kickoff_hour': kickoff_hour,
            'kickoff_day': kickoff_day,
            'is_weekend': is_weekend(kickoff_day),
        })

# Convert to DataFrame
data = pd.DataFrame(gameweek_data)

# Format columns and ensure correct data types
data['kickoff_time'] = pd.to_datetime(data['kickoff_time'], utc=True)
data['team_h_difficulty'] = data['team_h_difficulty'].astype('category')
data['team_a_difficulty'] = data['team_a_difficulty'].astype('category')
data['ict_index'] = pd.to_numeric(data['ict_index'], errors='coerce')
data['influence'] = pd.to_numeric(data['influence'], errors='coerce')
data['selected'] = pd.to_numeric(data['selected'], errors='coerce')

fixtures_file_path = 'https://raw.githubusercontent.com/vaastav/Fantasy-Premier-League/refs/heads/master/data/2024-25/fixtures.csv'
fixtures = pd.read_csv(fixtures_file_path)

# %%
# Check for missing values
data = data.dropna()

# %%
# Quick overview of the dataset
print("Dataset Overview:")
print(data.info())
print("\nSummary Statistics:")
print(data.describe())
# Out:
# Dataset Overview:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12034 entries, 0 to 12033
# Data columns (total 46 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   name                        12034 non-null  object
#  1   position                    12034 non-null  object
#  2   team                        12034 non-null  object
#  3   xP                          12034 non-null  int64
#  4   assists                     12034 non-null  int64
#  5   bonus                       12034 non-null  int64
#  6   bps                         12034 non-null  int64
#  7   clean_sheets                12034 non-null  int64
#  8   creativity                  12034 non-null  object
#  9   element                     12034 non-null  int64
#  10  expected_assists            12034 non-null  int64
#  11  expected_goal_involvements  12034 non-null  int64
#  12  expected_goals              12034 non-null  int64
#  13  expected_goals_conceded     12034 non-null  int64
#  14  fixture                     12034 non-null  int64
#  15  goals_conceded              12034 non-null  int64
#  16  goals_scored                12034 non-null  int64
#  17  ict_index                   12034 non-null  float64
#  18  influence                   12034 non-null  float64
#  19  kickoff_time                12034 non-null  datetime64[ns, UTC]
#  20  minutes                     12034 non-null  int64
#  21  opponent_team               12034 non-null  int64
#  22  own_goals                   12034 non-null  int64
#  23  penalties_missed            12034 non-null  int64
#  24  penalties_saved             12034 non-null  int64
#  25  red_cards                   12034 non-null  int64
#  26  round                       12034 non-null  int64
#  27  saves                       12034 non-null  int64
#  28  selected                    12034 non-null  float64
#  29  starts                      12034 non-null  int64
#  30  team_a_score                12034 non-null  int64
#  31  team_h_score                12034 non-null  int64
#  32  threat                      12034 non-null  object
#  33  total_points                12034 non-null  int64
#  34  transfers_balance           12034 non-null  int64
#  35  transfers_in                12034 non-null  int64
#  36  transfers_out               12034 non-null  int64
#  37  value                       12034 non-null  int64
#  38  was_home                    12034 non-null  bool
#  39  yellow_cards                12034 non-null  int64
#  40  GW                          12034 non-null  int64
#  41  team_h_difficulty           12034 non-null  category
#  42  team_a_difficulty           12034 non-null  category
#  43  kickoff_hour                12034 non-null  int64
#  44  kickoff_day                 12034 non-null  object
#  45  is_weekend                  12034 non-null  int64
# dtypes: bool(1), category(2), datetime64[ns, UTC](1), float64(3), int64(33), object(6)
# memory usage: 4.0+ MB
# None
#
# Summary Statistics:
#             xP       assists         bonus           bps  clean_sheets  \
# count  12034.0  12034.000000  12034.000000  12034.000000  12034.000000
# mean       0.0      0.038890      0.093901      5.065149      0.078943
# std        0.0      0.209831      0.458707      9.608331      0.269661
# min        0.0      0.000000      0.000000    -25.000000      0.000000
# 25%        0.0      0.000000      0.000000      0.000000      0.000000
# 50%        0.0      0.000000      0.000000      0.000000      0.000000
# 75%        0.0      0.000000      0.000000      7.000000      0.000000
# max        0.0      3.000000      3.000000     97.000000      1.000000
#
#             element  expected_assists  expected_goal_involvements  \
# count  12034.000000           12034.0                     12034.0
# mean     336.864135               0.0                         0.0
# std      194.929011               0.0                         0.0
# min        1.000000               0.0                         0.0
# 25%      168.000000               0.0                         0.0
# 50%      337.500000               0.0                         0.0
# 75%      505.000000               0.0                         0.0
# max      705.000000               0.0                         0.0
#
#        expected_goals  expected_goals_conceded  ...  team_h_score  \
# count         12034.0                  12034.0  ...  12034.000000
# mean              0.0                      0.0  ...      1.549776
# std               0.0                      0.0  ...      1.200248
# min               0.0                      0.0  ...      0.000000
# 25%               0.0                      0.0  ...      1.000000
# 50%               0.0                      0.0  ...      1.000000
# 75%               0.0                      0.0  ...      2.000000
# max               0.0                      0.0  ...      5.000000
#
#        total_points  transfers_balance  transfers_in  transfers_out  \
# count  12034.000000       1.203400e+04  1.203400e+04   1.203400e+04
# mean       1.216802      -4.949227e+02  3.397058e+05   3.402007e+05
# std        2.370863       4.283408e+05  8.074148e+05   7.540066e+05
# min       -5.000000      -2.553602e+06  0.000000e+00   0.000000e+00
# 25%        0.000000      -2.306500e+04  4.601000e+03   9.924500e+03
# 50%        0.000000      -3.223500e+03  3.248500e+04   4.466500e+04
# 75%        1.000000       3.865000e+03  2.405230e+05   2.909330e+05
# max       25.000000       3.571801e+06  5.883869e+06   6.769299e+06
#
#               value  yellow_cards            GW  kickoff_hour    is_weekend
# count  12034.000000  12034.000000  12034.000000   12034.00000  12034.000000
# mean      49.336131      0.068306      9.649161      15.12822      0.829068
# std       10.596210      0.252282      5.170305       2.22366      0.376465
# min       39.000000      0.000000      1.000000      11.00000      0.000000
# 25%       44.000000      0.000000      5.000000      14.00000      1.000000
# 50%       47.000000      0.000000     10.000000      15.00000      1.000000
# 75%       52.000000      0.000000     14.000000      16.00000      1.000000
# max      148.000000      1.000000     18.000000      20.00000      1.000000
#
# [8 rows x 36 columns]

# %%
# Data Preprocessing: Ensure numerical columns are in the correct type and drop unnecessary columns
data['xP'] = pd.to_numeric(data['xP'], errors='coerce')
data['total_points'] = pd.to_numeric(data['total_points'], errors='coerce')
data['transfers_balance'] = pd.to_numeric(data['transfers_balance'], errors='coerce')
data['value'] = pd.to_numeric(data['value'], errors='coerce')
data['threat'] = pd.to_numeric(data['threat'], errors='coerce')
data['creativity'] = pd.to_numeric(data['creativity'], errors='coerce')
data['team_h_difficulty'] = data['team_h_difficulty'].astype('category')
data['team_a_difficulty'] = data['team_a_difficulty'].astype('category')


# Convert kickoff_time to datetime
data['kickoff_time'] = pd.to_datetime(data['kickoff_time'], errors='coerce')

# Extract useful temporal features
data['kickoff_hour'] = data['kickoff_time'].dt.hour
data['kickoff_day'] = data['kickoff_time'].dt.day_name()
data['is_weekend'] = data['kickoff_time'].dt.weekday >= 5  # Saturday and Sunday as weekend
data['is_weekend'] = data['is_weekend'].astype(int)

# Drop rows where target column is missing
data = data.dropna(subset=['total_points'])

# Encoding categorical variables (for machine learning models)
data_model = pd.get_dummies(data, columns=['position', 'team', 'starts', 'team_h_difficulty', 'team_a_difficulty', 'kickoff_day'], drop_first=True)
data_model = data_model.drop(columns=['fixture'])
data_model = data_model.drop(columns=['kickoff_time', 'bps', 'bonus', 'xP'])

data_model.head()
# Out:
#                     name  assists  clean_sheets  creativity  element  \
# 0  Fábio Ferreira Vieira        0             0         0.0        1
# 1  Fábio Ferreira Vieira        0             0         0.0        1
# 2  Fábio Ferreira Vieira        0             0         0.0        1
# 3  Fábio Ferreira Vieira        0             0         0.0        1
# 4  Fábio Ferreira Vieira        0             0         0.0        1
#
#    expected_assists  expected_goal_involvements  expected_goals  \
# 0                 0                           0               0
# 1                 0                           0               0
# 2                 0                           0               0
# 3                 0                           0               0
# 4                 0                           0               0
#
#    expected_goals_conceded  goals_conceded  ...  team_h_difficulty_5  \
# 0                        0               0  ...                False
# 1                        0               0  ...                False
# 2                        0               0  ...                False
# 3                        0               0  ...                False
# 4                        0               0  ...                False
#
#    team_a_difficulty_3  team_a_difficulty_4  team_a_difficulty_5  \
# 0                False                False                 True
# 1                False                 True                False
# 2                False                False                 True
# 3                False                 True                False
# 4                False                 True                False
#
#    kickoff_day_Monday  kickoff_day_Saturday  kickoff_day_Sunday  \
# 0               False                  True               False
# 1               False                  True               False
# 2               False                  True               False
# 3               False                 False                True
# 4               False                 False                True
#
#    kickoff_day_Thursday  kickoff_day_Tuesday  kickoff_day_Wednesday
# 0                 False                False                  False
# 1                 False                False                  False
# 2                 False                False                  False
# 3                 False                False                  False
# 4                 False                False                  False
#
# [5 rows x 70 columns]

# %%
# Initialize H2O
h2o.init()

# Replace spaces, quotes, and strip columns in your data
data_model.columns = data_model.columns.str.replace(' ', '_').str.replace("'", "").str.strip()

# Convert your pandas DataFrame to H2OFrame
h2o_data = h2o.H2OFrame(data_model)

# Define target and features
target = 'total_points'
features = [col for col in h2o_data.columns if col != target]

# Split the data into train and test sets
train, test = h2o_data.split_frame(ratios=[0.8], seed=123)

# Run H2O's AutoML for regression
aml = H2OAutoML(
    max_runtime_secs=300,  # Adjust runtime as needed
    seed=123,
    stopping_metric='RMSE'
)
aml.train(x=features, y=target, training_frame=train)

# Get the best model
best_model = aml.leader
print(f"Best Model: {best_model}")

# Make predictions on the test set
predictions = best_model.predict(test)

# If you have future data, you can load it and make predictions similarly
# future_data = h2o.H2OFrame(your_future_data)
# future_predictions = best_model.predict(future_data)

# View predictions
predictions_df = predictions.as_data_frame()
print(predictions_df)
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321..... not found.
# Attempting to start a local H2O server...
# ; Java HotSpot(TM) 64-Bit Server VM (build 23.0.1+11-39, mixed mode, sharing)
#   Starting server from C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\h2o\backend\bin\h2o.jar
#   Ice root: C:\Users\user\AppData\Local\Temp\tmp2f1vmhq4
#   JVM stdout: C:\Users\user\AppData\Local\Temp\tmp2f1vmhq4\h2o_user_started_from_python.out
#   JVM stderr: C:\Users\user\AppData\Local\Temp\tmp2f1vmhq4\h2o_user_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# --------------------------  -----------------------------
# H2O_cluster_uptime:         01 secs
# H2O_cluster_timezone:       Europe/Lisbon
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.46.0.6
# H2O_cluster_version_age:    1 month and 25 days
# H2O_cluster_name:           H2O_from_python_user_1hh8t6
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    7.964 Gb
# H2O_cluster_total_cores:    8
# H2O_cluster_allowed_cores:  8
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://127.0.0.1:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.13.1 final
# --------------------------  -----------------------------
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |
# 00:04:49.532: AutoML: XGBoost is not available; skipping it.
# 00:04:49.556: _train param, Dropping bad and constant columns: [expected_goal_involvements, expected_goals, expected_assists, expected_goals_conceded]
#
# █
# 00:04:51.741: _train param, Dropping bad and constant columns: [expected_goal_involvements, expected_goals, expected_assists, expected_goals_conceded]
#
# ██
# 00:04:56.852: _train param, Dropping unused columns: [expected_goal_involvements, expected_goals, expected_assists, expected_goals_conceded]
# 00:04:57.172: _train param, Dropping bad and constant columns: [expected_goal_involvements, expected_goals, expected_assists, expected_goals_conceded]
#
# ██
# 00:05:01.41: _train param, Dropping bad and constant columns: [expected_goal_involvements, expected_goals, expected_assists, expected_goals_conceded]
#
# █
# 00:05:02.910: _train param, Dropping bad and constant columns: [expected_goal_involvements, expected_goals, expected_assists, expected_goals_conceded]
#
# █
# 00:05:05.38: _train param, Dropping bad and constant columns: [expected_goal_involvements, expected_goals, expected_assists, expected_goals_conceded]
#
# █
# 00:05:07.704: _train param, Dropping unused columns: [expected_goal_involvements, expected_goals, expected_assists, expected_goals_conceded]
# 00:05:07.941: _train param, Dropping unused columns: [expected_goal_involvements, expected_goals, expected_assists, expected_goals_conceded]
# 00:05:08.203: _train param, Dropping bad and constant columns: [expected_goal_involvements, expected_goals, expected_assists, expected_goals_conceded]
#
# █████
# 00:05:13.495: _train param, Dropping bad and constant columns: [expected_goal_involvements, expected_goals, expected_assists, expected_goals_conceded]
#
# █
# 00:05:15.206: _train param, Dropping bad and constant columns: [expected_goal_involvements, expected_goals, expected_assists, expected_goals_conceded]
#
# █
# 00:05:17.907: _train param, Dropping unused columns: [expected_goal_involvements, expected_goals, expected_assists, expected_goals_conceded]
# 00:05:18.130: _train param, Dropping unused columns: [expected_goal_involvements, expected_goals, expected_assists, expected_goals_conceded]
#
# █████████████████████████████████████████
# 00:09:19.220: _train param, Dropping unused columns: [expected_goal_involvements, expected_goals, expected_assists, expected_goals_conceded]
#
# █
# 00:09:19.531: _train param, Dropping unused columns: [expected_goal_involvements, expected_goals, expected_assists, expected_goals_conceded]
#
# █████
# 00:09:46.773: _train param, Dropping unused columns: [expected_goal_involvements, expected_goals, expected_assists, expected_goals_conceded]
#
#
# 00:09:47.305: _train param, Dropping bad and constant columns: [expected_goal_involvements, expected_goals, expected_assists, expected_goals_conceded]
#
# █| (done) 100%
#
# 00:09:48.862: _train param, Dropping unused columns: [expected_goal_involvements, expected_goals, expected_assists, expected_goals_conceded]
# 00:09:49.424: _train param, Dropping unused columns: [expected_goal_involvements, expected_goals, expected_assists, expected_goals_conceded]
#
# Best Model: Model Details
# =============
# H2OStackedEnsembleEstimator : Stacked Ensemble
# Model Key: StackedEnsemble_AllModels_4_AutoML_1_20241228_00449
#
#
# Model Summary for Stacked Ensemble:
# key                                        value
# -----------------------------------------  ----------------
# Stacking strategy                          cross_validation
# Number of base models (used / total)       10/74
# # GBM base models (used / total)           4/61
# # DeepLearning base models (used / total)  6/10
# # DRF base models (used / total)           0/2
# # GLM base models (used / total)           0/1
# Metalearner algorithm                      GLM
# Metalearner fold assignment scheme         Random
# Metalearner nfolds                         5
# Metalearner fold_column
# Custom metalearner hyperparameters         None
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on train data. **
#
# MSE: 0.055439854287409995
# RMSE: 0.23545669301892863
# MAE: 0.11480252326243007
# RMSLE: NaN
# Mean Residual Deviance: 0.055439854287409995
# R^2: 0.9901736914087822
# Null degrees of freedom: 9663
# Residual degrees of freedom: 9653
# Null deviance: 54524.1121688695
# Residual deviance: 535.7707518335302
# AIC: -503.45615258869077
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on cross-validation data. **
#
# MSE: 0.11200376738375392
# RMSE: 0.3346696391723544
# MAE: 0.15764468493864292
# RMSLE: NaN
# Mean Residual Deviance: 0.11200376738375392
# R^2: 0.9801481516169556
# Null degrees of freedom: 9663
# Residual degrees of freedom: 9653
# Null deviance: 54531.19598159175
# Residual deviance: 1082.404407996598
# AIC: 6292.5951118233825
#
# Cross-Validation Metrics Summary:
#                         mean      sd          cv_1_valid    cv_2_valid    cv_3_valid    cv_4_valid    cv_5_valid
# ----------------------  --------  ----------  ------------  ------------  ------------  ------------  ------------
# aic                     1273.82   156.677     1196.45       1465.8        1112.91       1416.1        1177.83
# loglikelihood           0         0           0             0             0             0             0
# mae                     0.157679  0.00573728  0.152893      0.164833      0.151484      0.162029      0.157154
# mean_residual_deviance  0.112048  0.00903467  0.105945      0.122889      0.101318      0.119441      0.110648
# mse                     0.112048  0.00903467  0.105945      0.122889      0.101318      0.119441      0.110648
# null_deviance           10906.2   603.824     10133.1       11668.7       11174.3       10482.3       11072.7
# r2                      0.980107  0.00179742  0.979303      0.979547      0.982028      0.977815      0.981844
# residual_deviance       216.481   17.9319     209.454       238.65        200.813       232.551       200.936
# rmse                    0.334518  0.0134896   0.325492      0.350555      0.318306      0.345602      0.332637
# rmsle                   nan       0           nan           nan           nan           nan           nan
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
#        predict
# 0    -0.021518
# 1    -0.034675
# 2    -0.029508
# 3     0.963892
# 4     5.483638
# ...        ...
# 2365  0.001393
# 2366 -0.004614
# 2367  0.003409
# 2368 -0.011559
# 2369 -0.011079
#
# [2370 rows x 1 columns]
# C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\h2o\frame.py:1983: H2ODependencyWarning: Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using multi-thread, install polars and pyarrow and use it as pandas_df = h2o_df.as_data_frame(use_multi_thread=True)
#
#   warnings.warn("Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using"

# %%
# Define numeric columns for which rolling averages will be calculated 
numeric_columns = [
    'goals_scored', 'assists', 'clean_sheets', 'creativity', 
    'expected_assists', 'expected_goal_involvements', 'expected_goals', 
    'expected_goals_conceded', 'goals_conceded', 'ict_index', 
    'influence', 'minutes', 'own_goals', 'penalties_missed', 'penalties_saved', 
    'red_cards', 'saves', 'selected', 'team_a_score', 'team_h_score', 
    'threat', 'total_points', 'transfers_balance', 'transfers_in', 
    'transfers_out', 'value', 'yellow_cards'
]

# Determine the last 5 GWs dynamically
max_gw = data_model['GW'].max()
last_5_gws = [max_gw - 4, max_gw - 3, max_gw - 2, max_gw - 1, max_gw]

# Filter data for the last 5 GWs
last_5_gws_data = data_model[data_model['GW'].isin(last_5_gws)]

# Define a function to calculate weighted average
def weighted_avg(group, weight_decay=0.5):
    weights = [(weight_decay ** i) for i in range(len(group))]
    weights.reverse()  # Reverse so recent weeks have higher weights
    return (group * weights).sum() / sum(weights)

# Apply the weighted rolling average calculation
rolling_avg_weighted = last_5_gws_data.groupby('name')[numeric_columns].apply(
    lambda df: df.apply(weighted_avg, weight_decay=0.8)  # Adjust decay factor as needed
).reset_index()

# Prepare the template for the next GW (dynamically set to max_gw + 1)
next_gw = max_gw + 1

# Ensure gw_template includes all players, using their most recent data
latest_data_per_player = data_model.sort_values(by=['name', 'GW']).groupby('name').last().reset_index()
gw_template = latest_data_per_player.copy()
gw_template['GW'] = next_gw

# Add team_h_difficulty and team_a_difficulty from the fixtures dataframe
next_gw_fixtures = fixtures[fixtures['event'] == next_gw]
team_difficulty = next_gw_fixtures[['team_h', 'team_h_difficulty', 'team_a', 'team_a_difficulty']]

# Create difficulty mappings
team_h_difficulty_map = team_difficulty.set_index('team_h')['team_h_difficulty'].to_dict()
team_a_difficulty_map = team_difficulty.set_index('team_a')['team_a_difficulty'].to_dict()

# Map difficulties to the gw_template
gw_template['team_h_difficulty'] = gw_template['opponent_team'].map(team_h_difficulty_map)
gw_template['team_a_difficulty'] = gw_template['opponent_team'].map(team_a_difficulty_map)

# Fill missing difficulties with a default value (e.g., average difficulty or 0)
default_difficulty = 3  # Replace with the average or a logical default value
gw_template['team_h_difficulty'] = gw_template['team_h_difficulty'].fillna(default_difficulty).astype('category')
gw_template['team_a_difficulty'] = gw_template['team_a_difficulty'].fillna(default_difficulty).astype('category')

# Fill NaN values in rolling_avg_weighted using the last recorded values for each player
filled_rolling_avg_weighted = rolling_avg_weighted.copy()
filled_rolling_avg_weighted = filled_rolling_avg_weighted.set_index('name')

# Ensure missing values are filled from the player's last recorded values in data_model
for column in numeric_columns:
    # Use the player's last non-NaN value from data_model
    filled_rolling_avg_weighted[column] = filled_rolling_avg_weighted[column].fillna(
        last_5_gws_data.sort_values(by=['name', 'GW']).groupby('name')[column].last()
    )

filled_rolling_avg_weighted.reset_index(inplace=True)

# Merge the updated rolling averages back into the template
fpl_input = gw_template.drop(columns=numeric_columns).merge(
    filled_rolling_avg_weighted, on='name', how='left'
)

# %%
# Convert the new input data to an H2OFrame
fpl_input_h2o = h2o.H2OFrame(fpl_input)

# Make predictions using the trained model
Predictions_new_week = best_model.predict(fpl_input_h2o)

# Convert predictions to pandas DataFrame for easy viewing
Predictions_new_week_df = Predictions_new_week.as_data_frame()

# Display the predictions
Predictions_new_week_df.head()
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
# C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\h2o\frame.py:1983: H2ODependencyWarning: Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using multi-thread, install polars and pyarrow and use it as pandas_df = h2o_df.as_data_frame(use_multi_thread=True)
#
#   warnings.warn("Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using"
#     predict
# 0  0.928201
# 1 -0.006825
# 2  2.285665
# 3  3.680210
# 4  2.652517

# %%
# Step 1: Convert H2O predictions to pandas DataFrame
Predictions_new_week_df = Predictions_new_week.as_data_frame()

# Step 2: Ensure the predictions DataFrame has the player 'name' column for merging
# If 'name' is not included in the predictions, merge Predictions_new_week_df with your original input data
Predictions_new_week_df = pd.concat([fpl_input.reset_index(drop=True), Predictions_new_week_df], axis=1)

# Step 3: Recreate unique_data from data_model
unique_data = data[['name', 'position', 'team']].drop_duplicates(subset='name')  # Include 'team'

# Step 4: Get the last known value for each player
last_known_values = data.groupby('name').last().reset_index()[['name', 'value']]

# Step 5: Merge the position and team columns into Predictions_new_week and add value from the last known record
merged_predictions = Predictions_new_week_df.merge(
    unique_data[['name', 'position', 'team']],  # Include 'team' in the merge
    on='name',
    how='left'
).merge(
    last_known_values.rename(columns={'value': 'last_known_value'}),  # Rename to avoid column conflict
    on='name',
    how='left'
)

# Step 6: Fill NaN values in 'value' column with the last known value for players who don't have a record in the last GW
merged_predictions['value'] = merged_predictions['value'].fillna(merged_predictions['last_known_value'])

# Step 7: Drop the helper column 'last_known_value'
merged_predictions.drop(columns=['last_known_value'], inplace=True)

# Step 8: Calculate Points per Million (PPM)
merged_predictions['PPM'] = merged_predictions['predict'] / merged_predictions['value']  # 'predict' is H2O's output column for predictions

# Step 9: Sort by PPM for better insights (optional)
merged_predictions = merged_predictions.sort_values(by='PPM', ascending=False)

# Step 10: Keep only the required columns
merged_predictions = merged_predictions[['name', 'predict', 'position', 'team', 'value', 'PPM']]

# Display the result
merged_predictions.head()
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\h2o\frame.py:1983: H2ODependencyWarning: Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using multi-thread, install polars and pyarrow and use it as pandas_df = h2o_df.as_data_frame(use_multi_thread=True)
#
#   warnings.warn("Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using"
#                   name   predict position           team  value       PPM
# 280       Jacob Murphy  9.535641      MID      Newcastle   50.0  0.190713
# 343    Jordan Pickford  8.729004      GKP        Everton   49.0  0.178143
# 160       Dean Huijsen  7.813265      DEF    Bournemouth   44.0  0.177574
# 384  Kepa Arrizabalaga  6.356116      GKP    Bournemouth   45.0  0.141247
# 44      Anthony Elanga  7.094374      MID  Nott'm Forest   51.0  0.139105

# %%
# Calculate Points per Million (PPM)
merged_predictions['PPM'] = merged_predictions['predict'] / ( merged_predictions['value'] / 10 )

# Analyze top players to buy

# Number of top players to recommend per position
top_n = 10

# Group by position and select top N players by `prediction_label`
top_players = merged_predictions.groupby('position').apply(
    lambda group: group.nlargest(top_n, 'predict')
).reset_index(drop=True)

# Sort the recommendations by position and PPM for better insights
top_players = top_players.sort_values(by=['position', 'PPM'], ascending=[True, False])

# Save the recommendations to a CSV for review
top_players.to_csv('top_player_recommendations_with_ppm.csv', index=False)

# Print the recommendations
top_players
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_38672\2980634518.py:10: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   top_players = merged_predictions.groupby('position').apply(
#                                 name    predict position            team  \
# 0                       Dean Huijsen   7.813265      DEF     Bournemouth
# 2                  Nikola Milenković   6.293922      DEF   Nott'm Forest
# 5                  Vitalii Mykolenko   5.645507      DEF         Everton
# 4                         Lewis Hall   5.996665      DEF       Newcastle
# 3                           Ola Aina   6.073460      DEF   Nott'm Forest
# 9                       Matt Doherty   5.121295      DEF          Wolves
# 8                     Illia Zabarnyi   5.193640      DEF     Bournemouth
# 6                    James Tarkowski   5.450379      DEF         Everton
# 7                    Tyrick Mitchell   5.261212      DEF  Crystal Palace
# 1                     William Saliba   6.445642      DEF         Arsenal
# 10                    Alexander Isak  11.991277      FWD       Newcastle
# 11  Matheus Santos Carneiro Da Cunha   8.321979      FWD          Wolves
# 12                        Cody Gakpo   6.073618      FWD       Liverpool
# 15                     Iliman Ndiaye   3.861336      FWD         Everton
# 13                       Kai Havertz   5.406947      FWD         Arsenal
# 17                        Jhon Durán   3.646172      FWD     Aston Villa
# 18            Rodrigo Muniz Carvalho   3.339326      FWD          Fulham
# 16         Gabriel Fernando de Jesus   3.750389      FWD         Arsenal
# 14          Dominic Solanke-Mitchell   3.885732      FWD           Spurs
# 19                         Enes Ünal   2.513868      FWD     Bournemouth
# 20                   Jordan Pickford   8.729004      GKP         Everton
# 21                 Kepa Arrizabalaga   6.356116      GKP     Bournemouth
# 22                         Matz Sels   5.375948      GKP   Nott'm Forest
# 24                   Martin Dúbravka   4.655499      GKP       Newcastle
# 25               José Malheiro de Sá   4.040118      GKP          Wolves
# 23                 David Raya Martin   5.031622      GKP         Arsenal
# 27                  Łukasz Fabiański   2.925412      GKP        West Ham
# 26                        Bernd Leno   3.560103      GKP          Fulham
# 29                      Mark Flekken   2.807886      GKP       Brentford
# 28                    Robert Sánchez   2.809964      GKP         Chelsea
# 31                      Jacob Murphy   9.535641      MID       Newcastle
# 33                    Anthony Elanga   7.094374      MID   Nott'm Forest
# 34                      Ismaïla Sarr   6.815151      MID  Crystal Palace
# 30                     Mohamed Salah  13.357554      MID       Liverpool
# 36                Morgan Gibbs-White   5.720676      MID   Nott'm Forest
# 35                    Anthony Gordon   6.516627      MID       Newcastle
# 38                  Dejan Kulusevski   5.104398      MID           Spurs
# 37                      Jarrod Bowen   5.458486      MID        West Ham
# 32                       Cole Palmer   8.001616      MID         Chelsea
# 39                    James Maddison   4.870650      MID           Spurs
#
#     value       PPM
# 0    44.0  1.775742
# 2    46.0  1.368244
# 5    43.0  1.312909
# 4    47.0  1.275886
# 3    50.0  1.214692
# 9    43.0  1.190999
# 8    44.0  1.180373
# 6    48.0  1.135496
# 7    48.0  1.096086
# 1    63.0  1.023118
# 10   91.0  1.317723
# 11   71.0  1.172110
# 12   72.0  0.843558
# 15   54.0  0.715062
# 13   79.0  0.684424
# 17   59.0  0.617995
# 18   55.0  0.607150
# 16   68.0  0.551528
# 14   75.0  0.518098
# 19   54.0  0.465531
# 20   49.0  1.781429
# 21   45.0  1.412470
# 22   47.0  1.143819
# 24   42.0  1.108452
# 25   43.0  0.939562
# 23   56.0  0.898504
# 27   41.0  0.713515
# 26   50.0  0.712021
# 29   45.0  0.623975
# 28   48.0  0.585409
# 31   50.0  1.907128
# 33   51.0  1.391054
# 34   58.0  1.175026
# 30  135.0  0.989448
# 36   63.0  0.908044
# 35   73.0  0.892689
# 38   64.0  0.797562
# 37   75.0  0.727798
# 32  113.0  0.708108
# 39   77.0  0.632552

# %%
### Add Calculations
# Calculate Points per Million (PPM)
merged_predictions['PPM'] = merged_predictions['predict'] / (merged_predictions['value'] / 10)

# Example adjustment for fixture difficulty
# Replace this with actual fixture difficulty data if available
if 'fixture_difficulty' in merged_predictions.columns:
    merged_predictions['adjusted_predict'] = (
        merged_predictions['predict'] * (1 - merged_predictions['fixture_difficulty'] / 10)
    )
else:
    merged_predictions['adjusted_predict'] = merged_predictions['predict']

## Step 2: Optimization
### Define Constraints
constraints = {
    "GKP": 2,  # Max 2 Goalkeepers
    "DEF": 5,  # Max 5 Defenders
    "MID": 5,  # Max 5 Midfielders
    "FWD": 3,  # Max 3 Forwards
}

budget = 100  # Example budget in million units
merged_predictions['selected'] = 0  # Binary variable: 1 if player is selected
merged_predictions['cost'] = merged_predictions['value'] / 10

# Objective function
c = -merged_predictions['adjusted_predict'].values  # Negate for maximization

# Constraints
A = [merged_predictions['cost'].values]  # Budget
b = [budget]

# Position constraints
for pos, max_players in constraints.items():
    A.append((merged_predictions['position'] == pos).astype(int).values)
    b.append(max_players)

# Team constraints (e.g., max 3 players per team)
teams = merged_predictions['team'].unique()
for team in teams:
    A.append((merged_predictions['team'] == team).astype(int).values)
    b.append(3)

# Bounds for each player (0 or 1)
bounds = [(0, 1) for _ in range(len(merged_predictions))]

# Solve optimization
result = linprog(c, A_ub=A, b_ub=b, bounds=bounds, method='highs')

# Add results
if result.success:
    merged_predictions['selected'] = result.x.round().astype(int)
else:
    print("Optimization failed! Check constraints and data.")

## Step 3: Analysis and Validation
### Selected Team
selected_team = merged_predictions[merged_predictions['selected'] == 1]
selected_team = selected_team.sort_values(by='position')

# Save the selected team to CSV
selected_team.to_csv('optimized_team.csv', index=False)

# Summary
print(f"Total Points: {selected_team['adjusted_predict'].sum()}")
print(f"Total Cost: {selected_team['cost'].sum()}")

## Step 4: Visualization
### Player Distribution by Position
selected_team['position'].value_counts().plot(kind='bar', title='Position Distribution')
plt.show()

### Top Players by Position
for position in constraints.keys():
    top_players = selected_team[selected_team['position'] == position]
    top_players.sort_values('adjusted_predict', ascending=False, inplace=True)
    print(f"Top {position} players:")
    display(top_players[['name', 'team', 'position', 'adjusted_predict', 'cost']])

### Points vs. Cost
plt.scatter(selected_team['cost'], selected_team['adjusted_predict'], c='blue')
plt.title('Points vs Cost for Selected Players')
plt.xlabel('Cost (in millions)')
plt.ylabel('Predicted Points')
plt.show()

## Step 5: Interactive Widget for Budget
### Interactive Adjustment
@widgets.interact(budget=(50, 150, 5))
def update_budget(budget):
    # Update optimization with new budget
    b[0] = budget
    result = linprog(c, A_ub=A, b_ub=b, bounds=bounds, method='highs')
    if result.success:
        merged_predictions['selected'] = result.x.round().astype(int)
        selected_team = merged_predictions[merged_predictions['selected'] == 1]
        selected_team = selected_team.sort_values(by='position')
        print(f"New Total Points: {selected_team['adjusted_predict'].sum()}")
        print(f"New Total Cost: {selected_team['cost'].sum()}")
        display(selected_team[['name', 'team', 'position', 'adjusted_predict', 'cost']])
    else:
        print("Optimization failed!")
# Out:
# Total Points: 118.89928288824319
# Total Cost: 98.5
# Top GKP players:
# C:\Users\user\AppData\Local\Temp\ipykernel_38672\408681902.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_players.sort_values('adjusted_predict', ascending=False, inplace=True)
#                   name         team position  adjusted_predict  cost
# 343    Jordan Pickford      Everton      GKP          8.729004   4.9
# 384  Kepa Arrizabalaga  Bournemouth      GKP          6.356116   4.5
# Top DEF players:
# C:\Users\user\AppData\Local\Temp\ipykernel_38672\408681902.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_players.sort_values('adjusted_predict', ascending=False, inplace=True)
#                   name           team position  adjusted_predict  cost
# 160       Dean Huijsen    Bournemouth      DEF          7.813265   4.4
# 687     William Saliba        Arsenal      DEF          6.445642   6.3
# 527  Nikola Milenković  Nott'm Forest      DEF          6.293922   4.6
# 536           Ola Aina  Nott'm Forest      DEF          6.073460   5.0
# 415         Lewis Hall      Newcastle      DEF          5.996665   4.7
# Top MID players:
# C:\Users\user\AppData\Local\Temp\ipykernel_38672\408681902.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_players.sort_values('adjusted_predict', ascending=False, inplace=True)
#                name            team position  adjusted_predict  cost
# 499   Mohamed Salah       Liverpool      MID         13.357554  13.5
# 280    Jacob Murphy       Newcastle      MID          9.535641   5.0
# 129     Cole Palmer         Chelsea      MID          8.001616  11.3
# 44   Anthony Elanga   Nott'm Forest      MID          7.094374   5.1
# 267    Ismaïla Sarr  Crystal Palace      MID          6.815151   5.8
# Top FWD players:
# C:\Users\user\AppData\Local\Temp\ipykernel_38672\408681902.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_players.sort_values('adjusted_predict', ascending=False, inplace=True)
#                                  name       team position  adjusted_predict  \
# 21                     Alexander Isak  Newcastle      FWD         11.991277
# 471  Matheus Santos Carneiro Da Cunha     Wolves      FWD          8.321979
# 128                        Cody Gakpo  Liverpool      FWD          6.073618
#
#      cost
# 21    9.1
# 471   7.1
# 128   7.2
# interactive(children=(IntSlider(value=100, description='budget', max=150, min=50, step=5), Output()), _dom_cla…

# %%
# Clean up H2O environment
h2o.cluster().shutdown()
# Out:
# H2O session _sid_acff closed.
